# %%
import pandas as pd
import requests
from time import sleep

# %%
url_root = 'https://pokeapi.co/api/v2/pokemon/'

# %%
id = 1
error_count = 0
pokedex = []
while error_count < 5:
    
    url = url_root + str(id)
    res = requests.get(url)
    if res.status_code == 200:
        data = res.json()
        
        # Extract data
        pokemon = {}
        pokemon['poke-name'] = data['name']
        pokemon['pokenumber'] = data['id']
        pokemon['height'] = data['height']
        pokemon['weight'] = data['weight']
        
        # Extract stats
        for k in data['stats']:
            pokemon[k['stat']['name']] = k['base_stat']

        print(f"{pokemon['poke-name']} added successfully")
        id += 1
        pokedex.append(pokemon)
        sleep(1)
    
    else:
        print(f'Pokemon {id} is missing from API')
        id += 1
        error_count += 1
        sleep(1)
# Out:
# bulbasaur added successfully
# ivysaur added successfully
# venusaur added successfully
# charmander added successfully
# charmeleon added successfully
# charizard added successfully
# squirtle added successfully
# wartortle added successfully
# blastoise added successfully
# caterpie added successfully
# metapod added successfully
# butterfree added successfully
# weedle added successfully
# kakuna added successfully
# beedrill added successfully
# pidgey added successfully
# pidgeotto added successfully
# pidgeot added successfully
# rattata added successfully
# raticate added successfully
# spearow added successfully
# fearow added successfully
# ekans added successfully
# arbok added successfully
# pikachu added successfully
# raichu added successfully
# sandshrew added successfully
# sandslash added successfully
# nidoran-f added successfully
# nidorina added successfully
# nidoqueen added successfully
# nidoran-m added successfully
# nidorino added successfully
# nidoking added successfully
# clefairy added successfully
# clefable added successfully
# vulpix added successfully
# ninetales added successfully
# jigglypuff added successfully
# wigglytuff added successfully
# zubat added successfully
# golbat added successfully
# oddish added successfully
# gloom added successfully
# vileplume added successfully
# paras added successfully
# parasect added successfully
# venonat added successfully
# venomoth added successfully
# diglett added successfully
# dugtrio added successfully
# meowth added successfully
# persian added successfully
# psyduck added successfully
# golduck added successfully
# mankey added successfully
# primeape added successfully
# growlithe added successfully
# arcanine added successfully
# poliwag added successfully
# poliwhirl added successfully
# poliwrath added successfully
# abra added successfully
# kadabra added successfully
# alakazam added successfully
# machop added successfully
# machoke added successfully
# machamp added successfully
# bellsprout added successfully
# weepinbell added successfully
# victreebel added successfully
# tentacool added successfully
# tentacruel added successfully
# geodude added successfully
# graveler added successfully
# golem added successfully
# ponyta added successfully
# rapidash added successfully
# slowpoke added successfully
# slowbro added successfully
# magnemite added successfully
# magneton added successfully
# farfetchd added successfully
# doduo added successfully
# dodrio added successfully
# seel added successfully
# dewgong added successfully
# grimer added successfully
# muk added successfully
# shellder added successfully
# cloyster added successfully
# gastly added successfully
# haunter added successfully
# gengar added successfully
# onix added successfully
# drowzee added successfully
# hypno added successfully
# krabby added successfully
# kingler added successfully
# voltorb added successfully
# electrode added successfully
# exeggcute added successfully
# exeggutor added successfully
# cubone added successfully
# marowak added successfully
# hitmonlee added successfully
# hitmonchan added successfully
# lickitung added successfully
# koffing added successfully
# weezing added successfully
# rhyhorn added successfully
# rhydon added successfully
# chansey added successfully
# tangela added successfully
# kangaskhan added successfully
# horsea added successfully
# seadra added successfully
# goldeen added successfully
# seaking added successfully
# staryu added successfully
# starmie added successfully
# mr-mime added successfully
# scyther added successfully
# jynx added successfully
# electabuzz added successfully
# magmar added successfully
# pinsir added successfully
# tauros added successfully
# magikarp added successfully

# %%
pokedex = pd.DataFrame(pokedex)

# %%
pokedex.head()

# %%
pokedex.rename(columns={'speed': 'speed_TARGET'}, inplace=True)

# %%
pokedex.to_csv('./data/pokedex.csv', index=False)
